# %% [markdown]
# # Étape 1 - Découvrir la fonction `etl`
#
# Objectif de cette étape : rien d'autre que charger les librairies nécessaires, puis
# inspecter le code source de la fonction maître `etl` avec `etl??`.
#
# `etl` (Extract - Transform - Load) est la fonction qui enchaîne les 4 briques du
# pré-traitement : `extract` -> `clean` -> `merge` -> `resample`. Elle renvoie un
# DataFrame propre, échantillonné à l'heure, avec les colonnes `order_date` et `cash_in`.

# %% [markdown]
# ## Importation des librairies
#
# `sys.path.append('..')` permet d'importer le package `foodcast` situé à la racine du projet
# (ce notebook est dans `forecasting/`, donc `..` pointe vers la racine).

# %%
import sys
sys.path.append('..')
import yaml
import logging
import logging.config
import pandas as pd
pd.set_option('display.min_rows', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
pd.set_option('max_colwidth', 400)
from foodcast.domain.transform import etl
import foodcast.settings as settings

with open(settings.LOGGING_CONFIGURATION_FILE, 'r') as f:
    logging.config.dictConfig(yaml.safe_load(f.read()))

# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sys
#       2 sys.path.append('..')
# ----> 3 import yaml
#       4 import logging
#       5 import logging.config
#       6 import pandas as pd
#
# ModuleNotFoundError: No module named 'yaml'

# %% [markdown]
# ## Inspecter `etl`
#
# La double interrogation `??` affiche la signature, la docstring **et** le code source complet
# de la fonction. (`?` seul n'affiche que la signature et la docstring.)

# %%
etl??
# Out:
# Object `etl` not found.
